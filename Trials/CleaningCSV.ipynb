# %%
import pandas as pd
from sqlalchemy import create_engine, text
import numpy as np
import sqlite3

# %%
df = pd.read_csv('Crime_Data_from_2020_to_Present_20241018.csv')

# %%
engine = create_engine('sqlite:///your_database.db')

# %%
#Checking the number of rows
num_rows = len(df)
print("Number of rows:", num_rows)
# Out:
# Number of rows: 986500

# %%
#Parsing the date strings
df['Date Occurred'] = pd.to_datetime(df['DATE OCC'], format='%m/%d/%Y %I:%M:%S %p')

# %%
#Checking the new datatype
print(df['Date Occurred'].dtype)
# Out:
# datetime64[ns]

# %%
#Checking the first ten rows
print(df[['DATE OCC', 'Date Occurred']].head(10))
# Out:
#                  DATE OCC Date Occurred
# 0  03/01/2020 12:00:00 AM    2020-03-01
# 1  02/08/2020 12:00:00 AM    2020-02-08
# 2  11/04/2020 12:00:00 AM    2020-11-04
# 3  03/10/2020 12:00:00 AM    2020-03-10
# 4  08/17/2020 12:00:00 AM    2020-08-17
# 5  12/01/2020 12:00:00 AM    2020-12-01
# 6  07/03/2020 12:00:00 AM    2020-07-03
# 7  05/12/2020 12:00:00 AM    2020-05-12
# 8  12/09/2020 12:00:00 AM    2020-12-09
# 9  12/31/2020 12:00:00 AM    2020-12-31

# %%
#Checking for null values
print(df['Date Occurred'].isnull().sum())
# Out:
# 0

# %%
#Finding the most recent date in the dataset and the date one year before
most_recent_date = df['Date Occurred'].max()
date_one_year_before = most_recent_date - pd.DateOffset(years=1)

print("Most Recent Date:", most_recent_date)
print("Date One Year Before:", date_one_year_before)
# Out:
# Most Recent Date: 2024-10-14 00:00:00
# Date One Year Before: 2023-10-14 00:00:00

# %%
#Filtering the dataframe to only data from the last year
start_of_year = pd.Timestamp('2023-10-14')
end_of_year = pd.Timestamp('2024-10-14')
recent_year_df = df[(df['Date Occurred'] >= start_of_year) & (df['Date Occurred'] <= end_of_year)]

# %%
#Checking the new number of rows
num_rows = len(recent_year_df)
print("Number of rows:", num_rows)
# Out:
# Number of rows: 159711

# %%
recent_year_df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 644791  230618504  12/01/2023 12:00:00 AM  12/01/2023 12:00:00 AM       110
# 644792  242105761  02/13/2024 12:00:00 AM  12/17/2023 12:00:00 AM       730
# 644793  230617683  11/10/2023 12:00:00 AM  11/08/2023 12:00:00 AM       800
# 644796  230514872  10/19/2023 12:00:00 AM  10/19/2023 12:00:00 AM      1520
# 644799  231225821  12/30/2023 12:00:00 AM  12/29/2023 12:00:00 AM      2200
# ...           ...                     ...                     ...       ...
# 986495  242011172  08/20/2024 12:00:00 AM  08/17/2024 12:00:00 AM      2300
# 986496  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 986497  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 986498  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 986499  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 644791     6    Hollywood          639         2     626
# 644792    21      Topanga         2149         1     210
# 644793     6    Hollywood          663         2     662
# 644796     5       Harbor          522         1     761
# 644799    12  77th Street         1251         1     510
# ...      ...          ...          ...       ...     ...
# 986495    20      Olympic         2033         1     341
# 986496     7     Wilshire          788         1     510
# 986497     1      Central          101         2     745
# 986498     3    Southwest          358         1     230
# 986499     9     Van Nuys          914         1     510
#
#                                               Crm Cd Desc  ...   Status Desc  \
# 644791                  INTIMATE PARTNER - SIMPLE ASSAULT  ...   Adult Other
# 644792                                            ROBBERY  ...   Adult Other
# 644793                                 BUNCO, GRAND THEFT  ...   Invest Cont
# 644796                                    BRANDISH WEAPON  ...  Adult Arrest
# 644799                                   VEHICLE - STOLEN  ...   Invest Cont
# ...                                                   ...  ...           ...
# 986495  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...   Invest Cont
# 986496                                   VEHICLE - STOLEN  ...   Invest Cont
# 986497           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...   Invest Cont
# 986498     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...   Invest Cont
# 986499                                   VEHICLE - STOLEN  ...   Invest Cont
#
#         Crm Cd 1 Crm Cd 2 Crm Cd 3  Crm Cd 4  \
# 644791     626.0      NaN      NaN       NaN
# 644792     210.0      NaN      NaN       NaN
# 644793     662.0      NaN      NaN       NaN
# 644796     761.0      NaN      NaN       NaN
# 644799     510.0      NaN      NaN       NaN
# ...          ...      ...      ...       ...
# 986495     341.0      NaN      NaN       NaN
# 986496     510.0      NaN      NaN       NaN
# 986497     745.0      NaN      NaN       NaN
# 986498     230.0      NaN      NaN       NaN
# 986499     510.0      NaN      NaN       NaN
#
#                                        LOCATION  \
# 644791  5400    RUSSELL                      AV
# 644792  6600    QUARTZ                       AV
# 644793  1200    SEWARD                       ST
# 644796   600 N  NEPTUNE                      AV
# 644799  7800    CRENSHAW                     BL
# ...                                         ...
# 986495  3700    WILSHIRE                     BL
# 986496  4000 W  23RD                         ST
# 986497  1300 W  SUNSET                       BL
# 986498          FLOWER                       ST
# 986499  6900    VESPER                       AV
#
#                            Cross Street      LAT       LON Date Occurred
# 644791                              NaN  34.1042 -118.3072    2023-12-01
# 644792                              NaN  34.1917 -118.5641    2023-12-17
# 644793                              NaN  34.0907 -118.3384    2023-11-08
# 644796                              NaN  33.7795 -118.2715    2023-10-19
# 644799                              NaN  33.9691 -118.3309    2023-12-29
# ...                                 ...      ...       ...           ...
# 986495                              NaN  34.0617 -118.3066    2024-08-17
# 986496                              NaN  34.0362 -118.3284    2024-07-23
# 986497                              NaN  34.0685 -118.2460    2024-01-15
# 986498  JEFFERSON                    BL  34.0215 -118.2868    2024-04-24
# 986499                              NaN  34.1961 -118.4510    2024-08-12
#
# [159711 rows x 29 columns]

# %%
#Writing the dataframe to SQLite
#recent_year_df.to_sql('LA_Crime', con=engine, if_exists='replace', index=False)

# %%
#Querying the SQLite database to verify the data
#with engine.connect() as connection:
    #result = connection.execute(text("SELECT * FROM LA_Crime LIMIT 5;"))
    #df_result = pd.DataFrame(result.fetchall(), columns=result.keys())

# %%
#Exporting the cleaned dataframe to a CSV
#recent_year_df.to_csv('output.csv')

# %%
#Checking all the crime codes in the dataset
unique_crime_codes = recent_year_df['Crm Cd'].unique()
print(unique_crime_codes)
# Out:
# [626 210 662 761 510 442 341 440 888 354 520 903 740 310 420 352 624 230
#  330 940 648 745 236 438 331 901 900 930 668 220 434 480 110 860 627 753
#  820 956 410 647 845 886 320 890 350 922 822 343 670 812 522 237 943 622
#  946 625 121 910 850 664 932 623 813 902 439 760 755 433 649 661 122 437
#  654 762 882 251 815 763 810 756 231 666 474 821 814 921 933 443 421 651
#  920 351 250 441 954 487 928 235 806 944 353 450 347 470 949 653 942 951
#  805 931 950 445 865 345 660 870 948 473 652 444 884 924 451 435 475 830
#  926 471 453 452 880]

# %%
print(f"Number of unique crime codes: {len(unique_crime_codes)}")
# Out:
# Number of unique crime codes: 131

# %%
unique_crime_codes = recent_year_df[['Crm Cd', 'Crm Cd Desc']].drop_duplicates()

# %%
for index, row in unique_crime_codes.iterrows():
    print(f"Crm Cd: {row['Crm Cd']}, Crm Cd Desc: {row['Crm Cd Desc']}")
# Out:
# Crm Cd: 626, Crm Cd Desc: INTIMATE PARTNER - SIMPLE ASSAULT
# Crm Cd: 210, Crm Cd Desc: ROBBERY
# Crm Cd: 662, Crm Cd Desc: BUNCO, GRAND THEFT
# Crm Cd: 761, Crm Cd Desc: BRANDISH WEAPON
# Crm Cd: 510, Crm Cd Desc: VEHICLE - STOLEN
# Crm Cd: 442, Crm Cd Desc: SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# Crm Cd: 341, Crm Cd Desc: THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD
# Crm Cd: 440, Crm Cd Desc: THEFT PLAIN - PETTY ($950 & UNDER)
# Crm Cd: 888, Crm Cd Desc: TRESPASSING
# Crm Cd: 354, Crm Cd Desc: THEFT OF IDENTITY
# Crm Cd: 520, Crm Cd Desc: VEHICLE - ATTEMPT STOLEN
# Crm Cd: 903, Crm Cd Desc: CONTEMPT OF COURT
# Crm Cd: 740, Crm Cd Desc: VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)
# Crm Cd: 310, Crm Cd Desc: BURGLARY
# Crm Cd: 420, Crm Cd Desc: THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# Crm Cd: 352, Crm Cd Desc: PICKPOCKET
# Crm Cd: 624, Crm Cd Desc: BATTERY - SIMPLE ASSAULT
# Crm Cd: 230, Crm Cd Desc: ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# Crm Cd: 330, Crm Cd Desc: BURGLARY FROM VEHICLE
# Crm Cd: 940, Crm Cd Desc: EXTORTION
# Crm Cd: 648, Crm Cd Desc: ARSON
# Crm Cd: 745, Crm Cd Desc: VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# Crm Cd: 236, Crm Cd Desc: INTIMATE PARTNER - AGGRAVATED ASSAULT
# Crm Cd: 438, Crm Cd Desc: RECKLESS DRIVING
# Crm Cd: 331, Crm Cd Desc: THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)
# Crm Cd: 901, Crm Cd Desc: VIOLATION OF RESTRAINING ORDER
# Crm Cd: 900, Crm Cd Desc: VIOLATION OF COURT ORDER
# Crm Cd: 930, Crm Cd Desc: CRIMINAL THREATS - NO WEAPON DISPLAYED
# Crm Cd: 668, Crm Cd Desc: EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)
# Crm Cd: 220, Crm Cd Desc: ATTEMPTED ROBBERY
# Crm Cd: 434, Crm Cd Desc: FALSE IMPRISONMENT
# Crm Cd: 480, Crm Cd Desc: BIKE - STOLEN
# Crm Cd: 110, Crm Cd Desc: CRIMINAL HOMICIDE
# Crm Cd: 860, Crm Cd Desc: BATTERY WITH SEXUAL CONTACT
# Crm Cd: 627, Crm Cd Desc: CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT
# Crm Cd: 753, Crm Cd Desc: DISCHARGE FIREARMS/SHOTS FIRED
# Crm Cd: 820, Crm Cd Desc: ORAL COPULATION
# Crm Cd: 956, Crm Cd Desc: LETTERS, LEWD  -  TELEPHONE CALLS, LEWD
# Crm Cd: 410, Crm Cd Desc: BURGLARY FROM VEHICLE, ATTEMPTED
# Crm Cd: 647, Crm Cd Desc: THROWING OBJECT AT MOVING VEHICLE
# Crm Cd: 845, Crm Cd Desc: SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# Crm Cd: 886, Crm Cd Desc: DISTURBING THE PEACE
# Crm Cd: 320, Crm Cd Desc: BURGLARY, ATTEMPTED
# Crm Cd: 890, Crm Cd Desc: FAILURE TO YIELD
# Crm Cd: 350, Crm Cd Desc: THEFT, PERSON
# Crm Cd: 922, Crm Cd Desc: CHILD STEALING
# Crm Cd: 822, Crm Cd Desc: HUMAN TRAFFICKING - COMMERCIAL SEX ACTS
# Crm Cd: 343, Crm Cd Desc: SHOPLIFTING-GRAND THEFT ($950.01 & OVER)
# Crm Cd: 670, Crm Cd Desc: EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)
# Crm Cd: 812, Crm Cd Desc: CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)
# Crm Cd: 522, Crm Cd Desc: VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, BIKES, ETC)
# Crm Cd: 237, Crm Cd Desc: CHILD NEGLECT (SEE 300 W.I.C.)
# Crm Cd: 943, Crm Cd Desc: CRUELTY TO ANIMALS
# Crm Cd: 622, Crm Cd Desc: BATTERY ON A FIREFIGHTER
# Crm Cd: 946, Crm Cd Desc: OTHER MISCELLANEOUS CRIME
# Crm Cd: 625, Crm Cd Desc: OTHER ASSAULT
# Crm Cd: 121, Crm Cd Desc: RAPE, FORCIBLE
# Crm Cd: 910, Crm Cd Desc: KIDNAPPING
# Crm Cd: 850, Crm Cd Desc: INDECENT EXPOSURE
# Crm Cd: 664, Crm Cd Desc: BUNCO, PETTY THEFT
# Crm Cd: 932, Crm Cd Desc: PEEPING TOM
# Crm Cd: 623, Crm Cd Desc: BATTERY POLICE (SIMPLE)
# Crm Cd: 813, Crm Cd Desc: CHILD ANNOYING (17YRS & UNDER)
# Crm Cd: 902, Crm Cd Desc: VIOLATION OF TEMPORARY RESTRAINING ORDER
# Crm Cd: 439, Crm Cd Desc: FALSE POLICE REPORT
# Crm Cd: 760, Crm Cd Desc: LEWD/LASCIVIOUS ACTS WITH CHILD
# Crm Cd: 755, Crm Cd Desc: BOMB SCARE
# Crm Cd: 433, Crm Cd Desc: DRIVING WITHOUT OWNER CONSENT (DWOC)
# Crm Cd: 649, Crm Cd Desc: DOCUMENT FORGERY / STOLEN FELONY
# Crm Cd: 661, Crm Cd Desc: UNAUTHORIZED COMPUTER ACCESS
# Crm Cd: 122, Crm Cd Desc: RAPE, ATTEMPTED
# Crm Cd: 437, Crm Cd Desc: RESISTING ARREST
# Crm Cd: 654, Crm Cd Desc: CREDIT CARDS, FRAUD USE ($950 & UNDER
# Crm Cd: 762, Crm Cd Desc: LEWD CONDUCT
# Crm Cd: 882, Crm Cd Desc: INCITING A RIOT
# Crm Cd: 251, Crm Cd Desc: SHOTS FIRED AT INHABITED DWELLING
# Crm Cd: 815, Crm Cd Desc: SEXUAL PENETRATION W/FOREIGN OBJECT
# Crm Cd: 763, Crm Cd Desc: STALKING
# Crm Cd: 810, Crm Cd Desc: SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W/ FRGN OBJ
# Crm Cd: 756, Crm Cd Desc: WEAPONS POSSESSION/BOMBING
# Crm Cd: 231, Crm Cd Desc: ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER
# Crm Cd: 666, Crm Cd Desc: BUNCO, ATTEMPT
# Crm Cd: 474, Crm Cd Desc: THEFT, COIN MACHINE - PETTY ($950 & UNDER)
# Crm Cd: 821, Crm Cd Desc: SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH
# Crm Cd: 814, Crm Cd Desc: CHILD PORNOGRAPHY
# Crm Cd: 921, Crm Cd Desc: HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE
# Crm Cd: 933, Crm Cd Desc: PROWLER
# Crm Cd: 443, Crm Cd Desc: SHOPLIFTING - ATTEMPT
# Crm Cd: 421, Crm Cd Desc: THEFT FROM MOTOR VEHICLE - ATTEMPT
# Crm Cd: 651, Crm Cd Desc: DOCUMENT WORTHLESS ($200.01 & OVER)
# Crm Cd: 920, Crm Cd Desc: KIDNAPPING - GRAND ATTEMPT
# Crm Cd: 351, Crm Cd Desc: PURSE SNATCHING
# Crm Cd: 250, Crm Cd Desc: SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT
# Crm Cd: 441, Crm Cd Desc: THEFT PLAIN - ATTEMPT
# Crm Cd: 954, Crm Cd Desc: CONTRIBUTING
# Crm Cd: 487, Crm Cd Desc: BOAT - STOLEN
# Crm Cd: 928, Crm Cd Desc: THREATENING PHONE CALLS/LETTERS
# Crm Cd: 235, Crm Cd Desc: CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT
# Crm Cd: 806, Crm Cd Desc: PANDERING
# Crm Cd: 944, Crm Cd Desc: CONSPIRACY
# Crm Cd: 353, Crm Cd Desc: DRUNK ROLL
# Crm Cd: 450, Crm Cd Desc: THEFT FROM PERSON - ATTEMPT
# Crm Cd: 347, Crm Cd Desc: GRAND THEFT / INSURANCE FRAUD
# Crm Cd: 470, Crm Cd Desc: TILL TAP - GRAND THEFT ($950.01 & OVER)
# Crm Cd: 949, Crm Cd Desc: ILLEGAL DUMPING
# Crm Cd: 653, Crm Cd Desc: CREDIT CARDS, FRAUD USE ($950.01 & OVER)
# Crm Cd: 942, Crm Cd Desc: BRIBERY
# Crm Cd: 951, Crm Cd Desc: DEFRAUDING INNKEEPER/THEFT OF SERVICES, $950 & UNDER
# Crm Cd: 805, Crm Cd Desc: PIMPING
# Crm Cd: 931, Crm Cd Desc: REPLICA FIREARMS(SALE,DISPLAY,MANUFACTURE OR DISTRIBUTE)
# Crm Cd: 950, Crm Cd Desc: DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $950.01
# Crm Cd: 445, Crm Cd Desc: DISHONEST EMPLOYEE ATTEMPTED THEFT
# Crm Cd: 865, Crm Cd Desc: DRUGS, TO A MINOR
# Crm Cd: 345, Crm Cd Desc: DISHONEST EMPLOYEE - GRAND THEFT
# Crm Cd: 660, Crm Cd Desc: COUNTERFEIT
# Crm Cd: 870, Crm Cd Desc: CHILD ABANDONMENT
# Crm Cd: 948, Crm Cd Desc: BIGAMY
# Crm Cd: 473, Crm Cd Desc: THEFT, COIN MACHINE - GRAND ($950.01 & OVER)
# Crm Cd: 652, Crm Cd Desc: DOCUMENT WORTHLESS ($200 & UNDER)
# Crm Cd: 444, Crm Cd Desc: DISHONEST EMPLOYEE - PETTY THEFT
# Crm Cd: 884, Crm Cd Desc: FAILURE TO DISPERSE
# Crm Cd: 924, Crm Cd Desc: TELEPHONE PROPERTY - DAMAGE
# Crm Cd: 451, Crm Cd Desc: PURSE SNATCHING - ATTEMPT
# Crm Cd: 435, Crm Cd Desc: LYNCHING
# Crm Cd: 475, Crm Cd Desc: THEFT, COIN MACHINE - ATTEMPT
# Crm Cd: 830, Crm Cd Desc: INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)
# Crm Cd: 926, Crm Cd Desc: TRAIN WRECKING
# Crm Cd: 471, Crm Cd Desc: TILL TAP - PETTY ($950 & UNDER)
# Crm Cd: 453, Crm Cd Desc: DRUNK ROLL - ATTEMPT
# Crm Cd: 452, Crm Cd Desc: PICKPOCKET, ATTEMPT
# Crm Cd: 880, Crm Cd Desc: DISRUPT SCHOOL

# %%
violent_crime_codes = ['110', '113', '121', '122', '815', '820', '821', '210', '220', '230', '231', '235', '236', '250', '251', '761', '926']

# %%
violent_crime_keywords = ['WEAPON', 'ASSAULT', 'ROBBERY', 'FALSE IMPRISONMENT', 'HOMICIDE', 'BATTERY', 'ABUSE', 'CHILD STEALING', 'HUMAN TRAFFICKING', 'RIOT', 'SHOTS FIRED', 'PENETRATION', 'STALKING', 'CHILD PORNOGRAPHY', 'NEGLECT', 'CRUELTY', 'RAPE', 'KIDNAPPING', 'BOMB SCARE', 'LYNCHING', 'THREATENING', 'CHILD ABUSE']

# %%
recent_year_df.loc[:, 'Classification'] = np.where(
    recent_year_df['Crm Cd Desc'].str.contains('|'.join(violent_crime_keywords), case=False, na=False),
    'Violent',
    'Non-Violent'
)
# Out:
# C:\Users\hebir\AppData\Local\Temp\ipykernel_8400\179397421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent_year_df.loc[:, 'Classification'] = np.where(

# %%
recent_year_df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 644791  230618504  12/01/2023 12:00:00 AM  12/01/2023 12:00:00 AM       110
# 644792  242105761  02/13/2024 12:00:00 AM  12/17/2023 12:00:00 AM       730
# 644793  230617683  11/10/2023 12:00:00 AM  11/08/2023 12:00:00 AM       800
# 644796  230514872  10/19/2023 12:00:00 AM  10/19/2023 12:00:00 AM      1520
# 644799  231225821  12/30/2023 12:00:00 AM  12/29/2023 12:00:00 AM      2200
# ...           ...                     ...                     ...       ...
# 986495  242011172  08/20/2024 12:00:00 AM  08/17/2024 12:00:00 AM      2300
# 986496  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 986497  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 986498  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 986499  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 644791     6    Hollywood          639         2     626
# 644792    21      Topanga         2149         1     210
# 644793     6    Hollywood          663         2     662
# 644796     5       Harbor          522         1     761
# 644799    12  77th Street         1251         1     510
# ...      ...          ...          ...       ...     ...
# 986495    20      Olympic         2033         1     341
# 986496     7     Wilshire          788         1     510
# 986497     1      Central          101         2     745
# 986498     3    Southwest          358         1     230
# 986499     9     Van Nuys          914         1     510
#
#                                               Crm Cd Desc  ... Crm Cd 1  \
# 644791                  INTIMATE PARTNER - SIMPLE ASSAULT  ...    626.0
# 644792                                            ROBBERY  ...    210.0
# 644793                                 BUNCO, GRAND THEFT  ...    662.0
# 644796                                    BRANDISH WEAPON  ...    761.0
# 644799                                   VEHICLE - STOLEN  ...    510.0
# ...                                                   ...  ...      ...
# 986495  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...    341.0
# 986496                                   VEHICLE - STOLEN  ...    510.0
# 986497           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...    745.0
# 986498     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...    230.0
# 986499                                   VEHICLE - STOLEN  ...    510.0
#
#         Crm Cd 2 Crm Cd 3 Crm Cd 4                                 LOCATION  \
# 644791       NaN      NaN      NaN  5400    RUSSELL                      AV
# 644792       NaN      NaN      NaN  6600    QUARTZ                       AV
# 644793       NaN      NaN      NaN  1200    SEWARD                       ST
# 644796       NaN      NaN      NaN   600 N  NEPTUNE                      AV
# 644799       NaN      NaN      NaN  7800    CRENSHAW                     BL
# ...          ...      ...      ...                                      ...
# 986495       NaN      NaN      NaN  3700    WILSHIRE                     BL
# 986496       NaN      NaN      NaN  4000 W  23RD                         ST
# 986497       NaN      NaN      NaN  1300 W  SUNSET                       BL
# 986498       NaN      NaN      NaN          FLOWER                       ST
# 986499       NaN      NaN      NaN  6900    VESPER                       AV
#
#                            Cross Street      LAT       LON Date Occurred  \
# 644791                              NaN  34.1042 -118.3072    2023-12-01
# 644792                              NaN  34.1917 -118.5641    2023-12-17
# 644793                              NaN  34.0907 -118.3384    2023-11-08
# 644796                              NaN  33.7795 -118.2715    2023-10-19
# 644799                              NaN  33.9691 -118.3309    2023-12-29
# ...                                 ...      ...       ...           ...
# 986495                              NaN  34.0617 -118.3066    2024-08-17
# 986496                              NaN  34.0362 -118.3284    2024-07-23
# 986497                              NaN  34.0685 -118.2460    2024-01-15
# 986498  JEFFERSON                    BL  34.0215 -118.2868    2024-04-24
# 986499                              NaN  34.1961 -118.4510    2024-08-12
#
#        Classification
# 644791        Violent
# 644792        Violent
# 644793    Non-Violent
# 644796        Violent
# 644799    Non-Violent
# ...               ...
# 986495    Non-Violent
# 986496    Non-Violent
# 986497    Non-Violent
# 986498        Violent
# 986499    Non-Violent
#
# [159711 rows x 30 columns]

# %%
unique_locations = recent_year_df['Premis Desc'].unique
print(unique_locations)
# Out:
# <bound method Series.unique of 644791    MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 644792                          SINGLE FAMILY DWELLING
# 644793    MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 644796                                  GARAGE/CARPORT
# 644799                                          STREET
#                               ...
# 986495                          BAR/COCKTAIL/NIGHTCLUB
# 986496                                          STREET
# 986497                                           HOTEL
# 986498                                        SIDEWALK
# 986499                                     PARKING LOT
# Name: Premis Desc, Length: 159711, dtype: object>

# %%
def assign_location(premis_desc):
    if isinstance(premis_desc, str):  # Check if the value is a string
        if 'DWELLING' in premis_desc:
            return 'Home'
        elif 'RESIDENCE' in premis_desc:
            return 'Home'
        elif 'WEBSITE' in premis_desc:
            return 'Online'
        elif 'ONLINE' in premis_desc:
            return 'Online'
        else:
            return 'Public'

# %%
recent_year_df.loc[:, 'Location Type'] = recent_year_df['Premis Desc'].apply(assign_location)
# Out:
# C:\Users\hebir\AppData\Local\Temp\ipykernel_8400\1414386483.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent_year_df.loc[:, 'Location Type'] = recent_year_df['Premis Desc'].apply(assign_location)

# %%
recent_year_df.columns = recent_year_df.columns.str.strip()

# %%
recent_year_df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 644791  230618504  12/01/2023 12:00:00 AM  12/01/2023 12:00:00 AM       110
# 644792  242105761  02/13/2024 12:00:00 AM  12/17/2023 12:00:00 AM       730
# 644793  230617683  11/10/2023 12:00:00 AM  11/08/2023 12:00:00 AM       800
# 644796  230514872  10/19/2023 12:00:00 AM  10/19/2023 12:00:00 AM      1520
# 644799  231225821  12/30/2023 12:00:00 AM  12/29/2023 12:00:00 AM      2200
# ...           ...                     ...                     ...       ...
# 986495  242011172  08/20/2024 12:00:00 AM  08/17/2024 12:00:00 AM      2300
# 986496  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 986497  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 986498  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 986499  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 644791     6    Hollywood          639         2     626
# 644792    21      Topanga         2149         1     210
# 644793     6    Hollywood          663         2     662
# 644796     5       Harbor          522         1     761
# 644799    12  77th Street         1251         1     510
# ...      ...          ...          ...       ...     ...
# 986495    20      Olympic         2033         1     341
# 986496     7     Wilshire          788         1     510
# 986497     1      Central          101         2     745
# 986498     3    Southwest          358         1     230
# 986499     9     Van Nuys          914         1     510
#
#                                               Crm Cd Desc  ... Crm Cd 2  \
# 644791                  INTIMATE PARTNER - SIMPLE ASSAULT  ...      NaN
# 644792                                            ROBBERY  ...      NaN
# 644793                                 BUNCO, GRAND THEFT  ...      NaN
# 644796                                    BRANDISH WEAPON  ...      NaN
# 644799                                   VEHICLE - STOLEN  ...      NaN
# ...                                                   ...  ...      ...
# 986495  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...      NaN
# 986496                                   VEHICLE - STOLEN  ...      NaN
# 986497           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...      NaN
# 986498     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...      NaN
# 986499                                   VEHICLE - STOLEN  ...      NaN
#
#         Crm Cd 3 Crm Cd 4                                 LOCATION  \
# 644791       NaN      NaN  5400    RUSSELL                      AV
# 644792       NaN      NaN  6600    QUARTZ                       AV
# 644793       NaN      NaN  1200    SEWARD                       ST
# 644796       NaN      NaN   600 N  NEPTUNE                      AV
# 644799       NaN      NaN  7800    CRENSHAW                     BL
# ...          ...      ...                                      ...
# 986495       NaN      NaN  3700    WILSHIRE                     BL
# 986496       NaN      NaN  4000 W  23RD                         ST
# 986497       NaN      NaN  1300 W  SUNSET                       BL
# 986498       NaN      NaN          FLOWER                       ST
# 986499       NaN      NaN  6900    VESPER                       AV
#
#                            Cross Street      LAT       LON Date Occurred  \
# 644791                              NaN  34.1042 -118.3072    2023-12-01
# 644792                              NaN  34.1917 -118.5641    2023-12-17
# 644793                              NaN  34.0907 -118.3384    2023-11-08
# 644796                              NaN  33.7795 -118.2715    2023-10-19
# 644799                              NaN  33.9691 -118.3309    2023-12-29
# ...                                 ...      ...       ...           ...
# 986495                              NaN  34.0617 -118.3066    2024-08-17
# 986496                              NaN  34.0362 -118.3284    2024-07-23
# 986497                              NaN  34.0685 -118.2460    2024-01-15
# 986498  JEFFERSON                    BL  34.0215 -118.2868    2024-04-24
# 986499                              NaN  34.1961 -118.4510    2024-08-12
#
#        Classification Location Type
# 644791        Violent          Home
# 644792        Violent          Home
# 644793    Non-Violent          Home
# 644796        Violent        Public
# 644799    Non-Violent        Public
# ...               ...           ...
# 986495    Non-Violent        Public
# 986496    Non-Violent        Public
# 986497    Non-Violent        Public
# 986498        Violent        Public
# 986499    Non-Violent        Public
#
# [159711 rows x 31 columns]

# %%
#Exporting the updated dataframe to a CSV
recent_year_df.to_csv('cleaned2.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[29], line 2
#       1 #Exporting the updated dataframe to a CSV
# ----> 2 recent_year_df.to_csv('cleaned2.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'cleaned2.csv'

# %%
#Writing the dataframe to SQLite
recent_year_df.to_sql('Cleaned_2', con=engine, if_exists='replace', index=False)

# %%
#Querying the SQLite database to verify the data
with engine.connect() as connection:
    result = connection.execute(text("SELECT * FROM Cleaned_2 LIMIT 5;"))
    df_result = pd.DataFrame(result.fetchall(), columns=result.keys())

# %%
conn = sqlite3.connect('your_database.db')

# %%
tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
tables_df = pd.read_sql_query(tables_query, conn)
print("Tables in the database:")
print(tables_df)
# Out:
# Tables in the database:
#         name
# 0  Cleaned_2

# %%
data_query = "SELECT * FROM Cleaned_2;"
data_df = pd.read_sql_query(data_query, conn)

# %%
print("Contents of the 'Cleaned_2' table:")
print(data_df)
# Out:
# Contents of the 'Cleaned_2' table:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0       230618504  12/01/2023 12:00:00 AM  12/01/2023 12:00:00 AM       110
# 1       242105761  02/13/2024 12:00:00 AM  12/17/2023 12:00:00 AM       730
# 2       230617683  11/10/2023 12:00:00 AM  11/08/2023 12:00:00 AM       800
# 3       230514872  10/19/2023 12:00:00 AM  10/19/2023 12:00:00 AM      1520
# 4       231225821  12/30/2023 12:00:00 AM  12/29/2023 12:00:00 AM      2200
# ...           ...                     ...                     ...       ...
# 159706  242011172  08/20/2024 12:00:00 AM  08/17/2024 12:00:00 AM      2300
# 159707  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 159708  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 159709  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 159710  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0          6    Hollywood          639         2     626
# 1         21      Topanga         2149         1     210
# 2          6    Hollywood          663         2     662
# 3          5       Harbor          522         1     761
# 4         12  77th Street         1251         1     510
# ...      ...          ...          ...       ...     ...
# 159706    20      Olympic         2033         1     341
# 159707     7     Wilshire          788         1     510
# 159708     1      Central          101         2     745
# 159709     3    Southwest          358         1     230
# 159710     9     Van Nuys          914         1     510
#
#                                               Crm Cd Desc  ... Crm Cd 2  \
# 0                       INTIMATE PARTNER - SIMPLE ASSAULT  ...      NaN
# 1                                                 ROBBERY  ...      NaN
# 2                                      BUNCO, GRAND THEFT  ...      NaN
# 3                                         BRANDISH WEAPON  ...      NaN
# 4                                        VEHICLE - STOLEN  ...      NaN
# ...                                                   ...  ...      ...
# 159706  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...      NaN
# 159707                                   VEHICLE - STOLEN  ...      NaN
# 159708           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...      NaN
# 159709     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...      NaN
# 159710                                   VEHICLE - STOLEN  ...      NaN
#
#         Crm Cd 3 Crm Cd 4                                 LOCATION  \
# 0            NaN      NaN  5400    RUSSELL                      AV
# 1            NaN      NaN  6600    QUARTZ                       AV
# 2            NaN      NaN  1200    SEWARD                       ST
# 3            NaN      NaN   600 N  NEPTUNE                      AV
# 4            NaN      NaN  7800    CRENSHAW                     BL
# ...          ...      ...                                      ...
# 159706       NaN      NaN  3700    WILSHIRE                     BL
# 159707       NaN      NaN  4000 W  23RD                         ST
# 159708       NaN      NaN  1300 W  SUNSET                       BL
# 159709       NaN      NaN          FLOWER                       ST
# 159710       NaN      NaN  6900    VESPER                       AV
#
#                            Cross Street      LAT       LON  \
# 0                                  None  34.1042 -118.3072
# 1                                  None  34.1917 -118.5641
# 2                                  None  34.0907 -118.3384
# 3                                  None  33.7795 -118.2715
# 4                                  None  33.9691 -118.3309
# ...                                 ...      ...       ...
# 159706                             None  34.0617 -118.3066
# 159707                             None  34.0362 -118.3284
# 159708                             None  34.0685 -118.2460
# 159709  JEFFERSON                    BL  34.0215 -118.2868
# 159710                             None  34.1961 -118.4510
#
#                      Date Occurred Classification Location Type
# 0       2023-12-01 00:00:00.000000        Violent          Home
# 1       2023-12-17 00:00:00.000000        Violent          Home
# 2       2023-11-08 00:00:00.000000    Non-Violent          Home
# 3       2023-10-19 00:00:00.000000        Violent        Public
# 4       2023-12-29 00:00:00.000000    Non-Violent        Public
# ...                            ...            ...           ...
# 159706  2024-08-17 00:00:00.000000    Non-Violent        Public
# 159707  2024-07-23 00:00:00.000000    Non-Violent        Public
# 159708  2024-01-15 00:00:00.000000    Non-Violent        Public
# 159709  2024-04-24 00:00:00.000000        Violent        Public
# 159710  2024-08-12 00:00:00.000000    Non-Violent        Public
#
# [159711 rows x 31 columns]

# %%
conn.close()
